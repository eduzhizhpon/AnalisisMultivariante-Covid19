# %% [markdown]
# <a href="https://colab.research.google.com/github/eddzhizhpon/AnalisisMultivariante-Covid19/blob/master/pruebas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hola():
  print("hola")
hola()
# Out:
# hola

# %%
def prueba():
  print("prueba")
prueba()
# Out:
# prueba
